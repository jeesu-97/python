# %%
### openapi 라이브러리 러드
import requests
from urllib import parse
import xmltodict
import pandas as pd

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\intco\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## openapi를 이용해서 서버와 통신하여 데이터를 가져오는 작업

## 어느 api에 접속할지 url 변수를 생성
url = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson"

## 공공데이터포털에서 주소와 함꼐 보내야되는 요청 변수

## 서비스 키
service_key = "dtbWOdJ%2FCz5HE0DGLU%2BCRPe7pOW0NIQBUcGEqsHZaTRiYCI%2F5%2BzugwzQjcvuId7NPdg6rUiW%2Bft3fm7yqyD4pw%3D%3D"

param =  {
    'serviceKey' : parse.unquote(service_key), ## unquote는 문자열을 요청변수화 시키는 함수
    'pageNo' : '1', ## 페이지 번호
    'numOfRows' : '5000', ## 페이지당 데이터의 수 
    'startCreateDt' : '20220101', ## 데이터의 시작일자
    'endCreateDt' : '20230210' ## 데이터의 마지막일자
}

## 서버에게 요청
response = requests.get(url, params=param) ## response는 xml 형태의 데이터

## xml 데이터를 dict 형태로 변환
result = xmltodict.parse(response.content)

print(result)

# %%
## result의 결과 안에 response 안에 body 안에 
## items 안에 item의 데이터

result['response']['body']['items']['item']
# Out:
# [{'createDt': '2023-02-10 04:22:09.0',
#   'deathCnt': '33697',
#   'decideCnt': '30325343',
#   'seq': '1159',
#   'stateDt': '20230210',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:02:40.0'},
#  {'createDt': '2023-02-09 00:13:08.0',
#   'deathCnt': '33680',
#   'decideCnt': '30311839',
#   'seq': '1158',
#   'stateDt': '20230209',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:03:21.0'},
#  {'createDt': '2023-02-08 00:10:49.0',
#   'deathCnt': '33646',
#   'decideCnt': '30297177',
#   'seq': '1157',
#   'stateDt': '20230208',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:03:54.0'},
#  {'createDt': '2023-02-07 04:25:43.0',
#   'deathCnt': '33624',
#   'decideCnt': '30279250',
#   'seq': '1156',
#   'stateDt': '20230207',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:04:17.0'},
#  {'createDt': '2023-02-06 04:20:35.0',
#   'deathCnt': '33614',
#   'decideCnt': '30263138',
#   'seq': '1155',
#   'stateDt': '20230206',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:04:43.0'},
#  {'createDt': '2023-02-05 00:20:31.0',
#   'deathCnt': '33596',
#   'decideCnt': '30257291',
#   'seq': '1154',
#   'stateDt': '20230205',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:05:08.0'},
#  {'createDt': '2023-02-04 00:08:43.0',
#   'deathCnt': '33574',
#   'decideCnt': '30243280',
#   'seq': '1153',
#   'stateDt': '20230204',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-11 06:05:59.0'},
#  {'createDt': '2023-02-03 05:52:19.0',
#   'deathCnt': '33552',
#   'decideCnt': '30228769',
#   'seq': '1152',
#   'stateDt': '20230203',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:09:18.0'},
#  {'createDt': '2023-02-02 04:52:36.0',
#   'deathCnt': '33522',
#   'decideCnt': '30213808',
#   'seq': '1151',
#   'stateDt': '20230202',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:09:36.0'},
#  {'createDt': '2023-02-01 01:24:28.0',
#   'deathCnt': '33486',
#   'decideCnt': '30196952',
#   'seq': '1150',
#   'stateDt': '20230201',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:10:06.0'},
#  {'createDt': '2023-01-31 00:02:09.0',
#   'deathCnt': '33444',
#   'decideCnt': '30176538',
#   'seq': '1149',
#   'stateDt': '20230131',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:10:16.0'},
#  {'createDt': '2023-01-30 05:43:27.0',
#   'deathCnt': '33420',
#   'decideCnt': '30156921',
#   'seq': '1148',
#   'stateDt': '20230130',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:10:26.0'},
#  {'createDt': '2023-01-29 04:38:06.0',
#   'deathCnt': '33390',
#   'decideCnt': '30149509',
#   'seq': '1147',
#   'stateDt': '20230129',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:10:36.0'},
#  {'createDt': '2023-01-28 01:05:22.0',
#   'deathCnt': '33361',
#   'decideCnt': '30130645',
#   'seq': '1146',
#   'stateDt': '20230128',
#   'stateTime': '00:00',
#   'updateDt': '2023-02-04 00:10:46.0'},
#  {'createDt': '2023-01-27 00:05:32.0',
#   'deathCnt': '33332',
#   'decideCnt': '30107118',
#   'seq': '1145',
#   'stateDt': '20230127',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:59.0'},
#  {'createDt': '2023-01-26 06:20:11.0',
#   'deathCnt': '33296',
#   'decideCnt': '30075407',
#   'seq': '1144',
#   'stateDt': '20230126',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:51.0'},
#  {'createDt': '2023-01-25 00:10:12.0',
#   'deathCnt': '33270',
#   'decideCnt': '30040321',
#   'seq': '1143',
#   'stateDt': '20230125',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:43.0'},
#  {'createDt': '2023-01-24 01:18:15.0',
#   'deathCnt': '33245',
#   'decideCnt': '30020794',
#   'seq': '1142',
#   'stateDt': '20230124',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:32.0'},
#  {'createDt': '2023-01-23 07:51:22.0',
#   'deathCnt': '33235',
#   'decideCnt': '30008544',
#   'seq': '1141',
#   'stateDt': '20230123',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:22.0'},
#  {'createDt': '2023-01-22 06:51:22.0',
#   'deathCnt': '33209',
#   'decideCnt': '29999327',
#   'seq': '1139',
#   'stateDt': '20230122',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:19:10.0'},
#  {'createDt': '2023-01-21 04:48:22.0',
#   'deathCnt': '33185',
#   'decideCnt': '29982710',
#   'seq': '1138',
#   'stateDt': '20230121',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-28 01:18:47.0'},
#  {'createDt': '2023-01-20 02:18:59.0',
#   'deathCnt': '33134',
#   'decideCnt': '29955251',
#   'seq': '1137',
#   'stateDt': '20230120',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:47:03.0'},
#  {'createDt': '2023-01-18 06:08:27.0',
#   'deathCnt': '33057',
#   'decideCnt': '29898037',
#   'seq': '1135',
#   'stateDt': '20230118',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:47:54.0'},
#  {'createDt': '2023-01-17 03:40:10.0',
#   'deathCnt': '33014',
#   'decideCnt': '29861141',
#   'seq': '1134',
#   'stateDt': '20230117',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:48:45.0'},
#  {'createDt': '2023-01-16 01:37:44.0',
#   'deathCnt': '32984',
#   'decideCnt': '29820957',
#   'seq': '1133',
#   'stateDt': '20230116',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:49:00.0'},
#  {'createDt': '2023-01-15 01:16:52.0',
#   'deathCnt': '32949',
#   'decideCnt': '29806827',
#   'seq': '1132',
#   'stateDt': '20230115',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:49:14.0'},
#  {'createDt': '2023-01-14 06:11:49.0',
#   'deathCnt': '32912',
#   'decideCnt': '29774267',
#   'seq': '1130',
#   'stateDt': '20230114',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-20 22:49:30.0'},
#  {'createDt': '2023-01-13 05:02:30.0',
#   'deathCnt': '32867',
#   'decideCnt': '29737622',
#   'seq': '1129',
#   'stateDt': '20230113',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 05:58:24.0'},
#  {'createDt': '2023-01-12 06:06:08.0',
#   'deathCnt': '32816',
#   'decideCnt': '29697896',
#   'seq': '1128',
#   'stateDt': '20230112',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 05:58:48.0'},
#  {'createDt': '2023-01-11 00:50:45.0',
#   'deathCnt': '32745',
#   'decideCnt': '29653947',
#   'seq': '1127',
#   'stateDt': '20230111',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 06:03:40.0'},
#  {'createDt': '2023-01-10 06:14:46.0',
#   'deathCnt': '32669',
#   'decideCnt': '29599614',
#   'seq': '1126',
#   'stateDt': '20230110',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 06:04:01.0'},
#  {'createDt': '2023-01-09 00:36:55.0',
#   'deathCnt': '32625',
#   'decideCnt': '29539590',
#   'seq': '1125',
#   'stateDt': '20230109',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 06:04:17.0'},
#  {'createDt': '2023-01-08 01:51:35.0',
#   'deathCnt': '32590',
#   'decideCnt': '29520501',
#   'seq': '1124',
#   'stateDt': '20230108',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 06:04:53.0'},
#  {'createDt': '2023-01-07 00:39:09.0',
#   'deathCnt': '32556',
#   'decideCnt': '29473758',
#   'seq': '1123',
#   'stateDt': '20230107',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-14 06:05:12.0'},
#  {'createDt': '2023-01-06 06:24:14.0',
#   'deathCnt': '32496',
#   'decideCnt': '29420027',
#   'seq': '1122',
#   'stateDt': '20230106',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:39:40.0'},
#  {'createDt': '2023-01-05 00:49:32.0',
#   'deathCnt': '32421',
#   'decideCnt': '29363073',
#   'seq': '1121',
#   'stateDt': '20230105',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:39:59.0'},
#  {'createDt': '2023-01-04 01:33:14.0',
#   'deathCnt': '32355',
#   'decideCnt': '29298979',
#   'seq': '1120',
#   'stateDt': '20230104',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:40:13.0'},
#  {'createDt': '2023-01-03 00:24:55.0',
#   'deathCnt': '32301',
#   'decideCnt': '29220425',
#   'seq': '1119',
#   'stateDt': '20230103',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:40:32.0'},
#  {'createDt': '2023-01-02 07:00:12.0',
#   'deathCnt': '32272',
#   'decideCnt': '29139386',
#   'seq': '1118',
#   'stateDt': '20230102',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:40:43.0'},
#  {'createDt': '2023-01-01 06:47:21.0',
#   'deathCnt': '32219',
#   'decideCnt': '29116662',
#   'seq': '1117',
#   'stateDt': '20230101',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:40:55.0'},
#  {'createDt': '2022-12-31 04:11:36.0',
#   'deathCnt': '32156',
#   'decideCnt': '29059161',
#   'seq': '1116',
#   'stateDt': '20221231',
#   'stateTime': '00:00',
#   'updateDt': '2023-01-07 00:41:09.0'},
#  {'createDt': '2022-12-30 00:46:13.0',
#   'deathCnt': '32095',
#   'decideCnt': '28996169',
#   'seq': '1115',
#   'stateDt': '20221230',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:11:58.0'},
#  {'createDt': '2022-12-29 01:53:10.0',
#   'deathCnt': '32027',
#   'decideCnt': '28930962',
#   'seq': '1114',
#   'stateDt': '20221229',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:12:11.0'},
#  {'createDt': '2022-12-28 03:55:40.0',
#   'deathCnt': '31951',
#   'decideCnt': '28859549',
#   'seq': '1113',
#   'stateDt': '20221228',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:12:23.0'},
#  {'createDt': '2022-12-27 01:09:19.0',
#   'deathCnt': '31882',
#   'decideCnt': '28772051',
#   'seq': '1112',
#   'stateDt': '20221227',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:12:32.0'},
#  {'createDt': '2022-12-26 00:48:49.0',
#   'deathCnt': '31832',
#   'decideCnt': '28684473',
#   'seq': '1111',
#   'stateDt': '20221226',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:12:43.0'},
#  {'createDt': '2022-12-25 06:48:15.0',
#   'deathCnt': '31790',
#   'decideCnt': '28658942',
#   'seq': '1110',
#   'stateDt': '20221225',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:12:53.0'},
#  {'createDt': '2022-12-24 01:09:15.0',
#   'deathCnt': '31744',
#   'decideCnt': '28600529',
#   'seq': '1109',
#   'stateDt': '20221224',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-31 04:13:03.0'},
#  {'createDt': '2022-12-23 03:14:07.0',
#   'deathCnt': '31674',
#   'decideCnt': '28534396',
#   'seq': '1108',
#   'stateDt': '20221223',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:10:05.0'},
#  {'createDt': '2022-12-22 01:18:07.0',
#   'deathCnt': '31611',
#   'decideCnt': '28466228',
#   'seq': '1107',
#   'stateDt': '20221222',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:10:31.0'},
#  {'createDt': '2022-12-21 05:36:53.0',
#   'deathCnt': '31549',
#   'decideCnt': '28390499',
#   'seq': '1106',
#   'stateDt': '20221221',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:10:41.0'},
#  {'createDt': '2022-12-20 02:52:56.0',
#   'deathCnt': '31490',
#   'decideCnt': '28302339',
#   'seq': '1105',
#   'stateDt': '20221220',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:10:51.0'},
#  {'createDt': '2022-12-19 04:05:07.0',
#   'deathCnt': '31434',
#   'decideCnt': '28214803',
#   'seq': '1104',
#   'stateDt': '20221219',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:11:03.0'},
#  {'createDt': '2022-12-18 01:01:22.0',
#   'deathCnt': '31395',
#   'decideCnt': '28188195',
#   'seq': '1103',
#   'stateDt': '20221218',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:11:14.0'},
#  {'createDt': '2022-12-17 05:14:33.0',
#   'deathCnt': '31353',
#   'decideCnt': '28129357',
#   'seq': '1102',
#   'stateDt': '20221217',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-24 01:11:26.0'},
#  {'createDt': '2022-12-16 05:48:50.0',
#   'deathCnt': '31298',
#   'decideCnt': '28062501',
#   'seq': '1101',
#   'stateDt': '20221216',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:09:55.0'},
#  {'createDt': '2022-12-15 00:54:32.0',
#   'deathCnt': '31232',
#   'decideCnt': '27995548',
#   'seq': '1100',
#   'stateDt': '20221215',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:10:34.0'},
#  {'createDt': '2022-12-14 00:42:41.0',
#   'deathCnt': '31174',
#   'decideCnt': '27925405',
#   'seq': '1099',
#   'stateDt': '20221214',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:11:09.0'},
#  {'createDt': '2022-12-13 04:34:20.0',
#   'deathCnt': '31128',
#   'decideCnt': '27840852',
#   'seq': '1098',
#   'stateDt': '20221213',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:11:38.0'},
#  {'createDt': '2022-12-12 00:34:36.0',
#   'deathCnt': '31099',
#   'decideCnt': '27754022',
#   'seq': '1097',
#   'stateDt': '20221212',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:12:02.0'},
#  {'createDt': '2022-12-11 01:10:06.0',
#   'deathCnt': '31069',
#   'decideCnt': '27728365',
#   'seq': '1096',
#   'stateDt': '20221211',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:12:25.0'},
#  {'createDt': '2022-12-10 00:41:17.0',
#   'deathCnt': '31029',
#   'decideCnt': '27674067',
#   'seq': '1095',
#   'stateDt': '20221210',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-17 05:12:45.0'},
#  {'createDt': '2022-12-09 05:42:28.0',
#   'deathCnt': '30975',
#   'decideCnt': '27611425',
#   'seq': '1094',
#   'stateDt': '20221209',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:42:22.0'},
#  {'createDt': '2022-12-08 01:09:53.0',
#   'deathCnt': '30908',
#   'decideCnt': '27548691',
#   'seq': '1093',
#   'stateDt': '20221208',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:42:32.0'},
#  {'createDt': '2022-12-07 01:05:13.0',
#   'deathCnt': '30847',
#   'decideCnt': '27483446',
#   'seq': '1092',
#   'stateDt': '20221207',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:42:43.0'},
#  {'createDt': '2022-12-06 01:00:52.0',
#   'deathCnt': '30793',
#   'decideCnt': '27408749',
#   'seq': '1091',
#   'stateDt': '20221206',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:42:59.0'},
#  {'createDt': '2022-12-05 06:19:02.0',
#   'deathCnt': '30769',
#   'decideCnt': '27331159',
#   'seq': '1090',
#   'stateDt': '20221205',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:43:11.0'},
#  {'createDt': '2022-12-04 03:41:12.0',
#   'deathCnt': '30729',
#   'decideCnt': '27308006',
#   'seq': '1089',
#   'stateDt': '20221204',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:43:22.0'},
#  {'createDt': '2022-12-03 03:50:44.0',
#   'deathCnt': '30669',
#   'decideCnt': '27261456',
#   'seq': '1088',
#   'stateDt': '20221203',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-10 00:43:36.0'},
#  {'createDt': '2022-12-02 00:21:56.0',
#   'deathCnt': '30621',
#   'decideCnt': '27208665',
#   'seq': '1087',
#   'stateDt': '20221202',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:51:16.0'},
#  {'createDt': '2022-12-01 03:39:22.0',
#   'deathCnt': '30568',
#   'decideCnt': '27155678',
#   'seq': '1086',
#   'stateDt': '20221201',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:51:26.0'},
#  {'createDt': '2022-11-30 02:39:44.0',
#   'deathCnt': '30506',
#   'decideCnt': '27098609',
#   'seq': '1085',
#   'stateDt': '20221130',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:51:38.0'},
#  {'createDt': '2022-11-29 01:57:16.0',
#   'deathCnt': '30454',
#   'decideCnt': '27031207',
#   'seq': '1084',
#   'stateDt': '20221129',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:51:51.0'},
#  {'createDt': '2022-11-28 01:52:34.0',
#   'deathCnt': '30413',
#   'decideCnt': '26959746',
#   'seq': '1083',
#   'stateDt': '20221128',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:52:04.0'},
#  {'createDt': '2022-11-27 05:04:03.0',
#   'deathCnt': '30369',
#   'decideCnt': '26937433',
#   'seq': '1082',
#   'stateDt': '20221127',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:52:15.0'},
#  {'createDt': '2022-11-26 04:08:52.0',
#   'deathCnt': '30330',
#   'decideCnt': '26890423',
#   'seq': '1081',
#   'stateDt': '20221126',
#   'stateTime': '00:00',
#   'updateDt': '2022-12-03 03:52:26.0'},
#  {'createDt': '2022-11-25 00:55:13.0',
#   'deathCnt': '30278',
#   'decideCnt': '26837700',
#   'seq': '1080',
#   'stateDt': '20221125',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 03:51:31.0'},
#  {'createDt': '2022-11-24 00:40:47.0',
#   'deathCnt': '30223',
#   'decideCnt': '26784002',
#   'seq': '1079',
#   'stateDt': '20221124',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:01:38.0'},
#  {'createDt': '2022-11-23 05:05:29.0',
#   'deathCnt': '30164',
#   'decideCnt': '26724920',
#   'seq': '1078',
#   'stateDt': '20221123',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:02:34.0'},
#  {'createDt': '2022-11-22 04:11:11.0',
#   'deathCnt': '30111',
#   'decideCnt': '26654614',
#   'seq': '1077',
#   'stateDt': '20221122',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:03:03.0'},
#  {'createDt': '2022-11-21 01:24:08.0',
#   'deathCnt': '30066',
#   'decideCnt': '26581754',
#   'seq': '1076',
#   'stateDt': '20221121',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:03:21.0'},
#  {'createDt': '2022-11-20 00:34:59.0',
#   'deathCnt': '30031',
#   'decideCnt': '26558677',
#   'seq': '1075',
#   'stateDt': '20221120',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:03:50.0'},
#  {'createDt': '2022-11-19 05:42:54.0',
#   'deathCnt': '29990',
#   'decideCnt': '26512679',
#   'seq': '1074',
#   'stateDt': '20221119',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-26 04:04:10.0'},
#  {'createDt': '2022-11-18 03:18:10.0',
#   'deathCnt': '29925',
#   'decideCnt': '26462165',
#   'seq': '1073',
#   'stateDt': '20221118',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:37:00.0'},
#  {'createDt': '2022-11-17 01:41:53.0',
#   'deathCnt': '29862',
#   'decideCnt': '26412747',
#   'seq': '1072',
#   'stateDt': '20221117',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:37:50.0'},
#  {'createDt': '2022-11-16 01:27:17.0',
#   'deathCnt': '29795',
#   'decideCnt': '26357323',
#   'seq': '1071',
#   'stateDt': '20221116',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:38:45.0'},
#  {'createDt': '2022-11-15 02:13:39.0',
#   'deathCnt': '29748',
#   'decideCnt': '26290754',
#   'seq': '1070',
#   'stateDt': '20221115',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:39:21.0'},
#  {'createDt': '2022-11-14 06:27:50.0',
#   'deathCnt': '29709',
#   'decideCnt': '26217888',
#   'seq': '1069',
#   'stateDt': '20221114',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:39:46.0'},
#  {'createDt': '2022-11-13 01:21:47.0',
#   'deathCnt': '29665',
#   'decideCnt': '26194137',
#   'seq': '1068',
#   'stateDt': '20221113',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:40:06.0'},
#  {'createDt': '2022-11-12 00:39:24.0',
#   'deathCnt': '29617',
#   'decideCnt': '26145695',
#   'seq': '1067',
#   'stateDt': '20221112',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-19 05:40:26.0'},
#  {'createDt': '2022-11-11 06:37:35.0',
#   'deathCnt': '29571',
#   'decideCnt': '26091436',
#   'seq': '1066',
#   'stateDt': '20221111',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:40:33.0'},
#  {'createDt': '2022-11-10 03:09:27.0',
#   'deathCnt': '29531',
#   'decideCnt': '26036917',
#   'seq': '1065',
#   'stateDt': '20221110',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:40:51.0'},
#  {'createDt': '2022-11-09 01:43:42.0',
#   'deathCnt': '29479',
#   'decideCnt': '25981560',
#   'seq': '1064',
#   'stateDt': '20221109',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:41:05.0'},
#  {'createDt': '2022-11-08 02:06:57.0',
#   'deathCnt': '29420',
#   'decideCnt': '25919092',
#   'seq': '1063',
#   'stateDt': '20221108',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:41:45.0'},
#  {'createDt': '2022-11-07 05:39:18.0',
#   'deathCnt': '29390',
#   'decideCnt': '25856832',
#   'seq': '1062',
#   'stateDt': '20221107',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:41:56.0'},
#  {'createDt': '2022-11-06 03:44:25.0',
#   'deathCnt': '29372',
#   'decideCnt': '25838167',
#   'seq': '1061',
#   'stateDt': '20221106',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:42:07.0'},
#  {'createDt': '2022-11-05 01:10:56.0',
#   'deathCnt': '29354',
#   'decideCnt': '25801502',
#   'seq': '1060',
#   'stateDt': '20221105',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-12 00:42:16.0'},
#  {'createDt': '2022-11-04 00:48:07.0',
#   'deathCnt': '29313',
#   'decideCnt': '25760661',
#   'seq': '1059',
#   'stateDt': '20221104',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:06:47.0'},
#  {'createDt': '2022-11-03 02:04:05.0',
#   'deathCnt': '29278',
#   'decideCnt': '25717212',
#   'seq': '1058',
#   'stateDt': '20221103',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:06:38.0'},
#  {'createDt': '2022-11-02 01:02:39.0',
#   'deathCnt': '29237',
#   'decideCnt': '25670325',
#   'seq': '1057',
#   'stateDt': '20221102',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:06:28.0'},
#  {'createDt': '2022-11-01 06:45:13.0',
#   'deathCnt': '29207',
#   'decideCnt': '25615588',
#   'seq': '1056',
#   'stateDt': '20221101',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:06:19.0'},
#  {'createDt': '2022-10-31 00:40:23.0',
#   'deathCnt': '29174',
#   'decideCnt': '25557225',
#   'seq': '1055',
#   'stateDt': '20221031',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:05:58.0'},
#  {'createDt': '2022-10-30 00:58:32.0',
#   'deathCnt': '29156',
#   'decideCnt': '25538721',
#   'seq': '1053',
#   'stateDt': '20221030',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:05:44.0'},
#  {'createDt': '2022-10-29 03:48:28.0',
#   'deathCnt': '29129',
#   'decideCnt': '25504229',
#   'seq': '1051',
#   'stateDt': '20221029',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:05:21.0'},
#  {'createDt': '2022-10-28 08:41:24.0',
#   'deathCnt': '29098',
#   'decideCnt': '25466926',
#   'seq': '1050',
#   'stateDt': '20221028',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:13:35.0'},
#  {'createDt': '2022-10-27 08:14:14.0',
#   'deathCnt': '29068',
#   'decideCnt': '25431015',
#   'seq': '1049',
#   'stateDt': '20221027',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:14:06.0'},
#  {'createDt': '2022-10-26 09:35:56.0',
#   'deathCnt': '29042',
#   'decideCnt': '25396051',
#   'seq': '1048',
#   'stateDt': '20221026',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:15:10.0'},
#  {'createDt': '2022-10-25 08:55:13.0',
#   'deathCnt': '29016',
#   'decideCnt': '25355235',
#   'seq': '1047',
#   'stateDt': '20221025',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:15:22.0'},
#  {'createDt': '2022-10-24 08:16:23.0',
#   'deathCnt': '28999',
#   'decideCnt': '25311496',
#   'seq': '1046',
#   'stateDt': '20221024',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:15:54.0'},
#  {'createDt': '2022-10-23 07:34:23.0',
#   'deathCnt': '28989',
#   'decideCnt': '25297200',
#   'seq': '1045',
#   'stateDt': '20221023',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:16:08.0'},
#  {'createDt': '2022-10-22 07:11:48.0',
#   'deathCnt': '28973',
#   'decideCnt': '25270966',
#   'seq': '1044',
#   'stateDt': '20221022',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:16:24.0'},
#  {'createDt': '2022-10-21 08:07:57.0',
#   'deathCnt': '28951',
#   'decideCnt': '25244085',
#   'seq': '1043',
#   'stateDt': '20221021',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:16:47.0'},
#  {'createDt': '2022-10-20 08:11:38.0',
#   'deathCnt': '28921',
#   'decideCnt': '25219364',
#   'seq': '1042',
#   'stateDt': '20221020',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:17:09.0'},
#  {'createDt': '2022-10-19 08:33:50.0',
#   'deathCnt': '28898',
#   'decideCnt': '25194010',
#   'seq': '1041',
#   'stateDt': '20221019',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:17:26.0'},
#  {'createDt': '2022-10-18 09:03:59.0',
#   'deathCnt': '28855',
#   'decideCnt': '25164531',
#   'seq': '1040',
#   'stateDt': '20221018',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:17:45.0'},
#  {'createDt': '2022-10-17 09:14:46.0',
#   'deathCnt': '28849',
#   'decideCnt': '25131323',
#   'seq': '1039',
#   'stateDt': '20221017',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:18:25.0'},
#  {'createDt': '2022-10-16 07:52:46.0',
#   'deathCnt': '28839',
#   'decideCnt': '25120298',
#   'seq': '1038',
#   'stateDt': '20221016',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:18:38.0'},
#  {'createDt': '2022-10-15 00:52:25.0',
#   'deathCnt': '28807',
#   'decideCnt': '25098842',
#   'seq': '1037',
#   'stateDt': '20221015',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:18:52.0'},
#  {'createDt': '2022-10-14 08:10:05.0',
#   'deathCnt': '28782',
#   'decideCnt': '25076037',
#   'seq': '1036',
#   'stateDt': '20221014',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:19:04.0'},
#  {'createDt': '2022-10-13 08:12:27.0',
#   'deathCnt': '28747',
#   'decideCnt': '25052478',
#   'seq': '1035',
#   'stateDt': '20221013',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:19:16.0'},
#  {'createDt': '2022-10-12 07:48:38.0',
#   'deathCnt': '28722',
#   'decideCnt': '25025576',
#   'seq': '1034',
#   'stateDt': '20221012',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:19:29.0'},
#  {'createDt': '2022-10-11 04:40:47.0',
#   'deathCnt': '28707',
#   'decideCnt': '24995060',
#   'seq': '1033',
#   'stateDt': '20221011',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:19:53.0'},
#  {'createDt': '2022-10-10 01:05:43.0',
#   'deathCnt': '28697',
#   'decideCnt': '24979634',
#   'seq': '1032',
#   'stateDt': '20221010',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:20:09.0'},
#  {'createDt': '2022-10-09 07:06:18.0',
#   'deathCnt': '28674',
#   'decideCnt': '24970659',
#   'seq': '1031',
#   'stateDt': '20221009',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:20:24.0'},
#  {'createDt': '2022-10-08 01:56:04.0',
#   'deathCnt': '28645',
#   'decideCnt': '24953013',
#   'seq': '1030',
#   'stateDt': '20221008',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:20:37.0'},
#  {'createDt': '2022-10-07 08:39:43.0',
#   'deathCnt': '28613',
#   'decideCnt': '24933664',
#   'seq': '1029',
#   'stateDt': '20221007',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:20:49.0'},
#  {'createDt': '2022-10-06 09:07:29.0',
#   'deathCnt': '28572',
#   'decideCnt': '24911380',
#   'seq': '1028',
#   'stateDt': '20221006',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:21:05.0'},
#  {'createDt': '2022-10-05 09:02:10.0',
#   'deathCnt': '28543',
#   'decideCnt': '24882756',
#   'seq': '1027',
#   'stateDt': '20221005',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:21:16.0'},
#  {'createDt': '2022-10-04 09:19:41.0',
#   'deathCnt': '28527',
#   'decideCnt': '24848037',
#   'seq': '1026',
#   'stateDt': '20221004',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:21:26.0'},
#  {'createDt': '2022-10-03 08:18:34.0',
#   'deathCnt': '28508',
#   'decideCnt': '24831622',
#   'seq': '1025',
#   'stateDt': '20221003',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:21:39.0'},
#  {'createDt': '2022-10-02 08:39:32.0',
#   'deathCnt': '28489',
#   'decideCnt': '24819480',
#   'seq': '1023',
#   'stateDt': '20221002',
#   'stateTime': '00:00',
#   'updateDt': '2022-10-08 01:57:58.0'},
#  {'createDt': '2022-10-01 08:00:57.0',
#   'deathCnt': '28444',
#   'decideCnt': '24795902',
#   'seq': '1022',
#   'stateDt': '20221001',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:22:13.0'},
#  {'createDt': '2022-09-30 08:15:52.0',
#   'deathCnt': '28405',
#   'decideCnt': '24768984',
#   'seq': '1021',
#   'stateDt': '20220930',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:33:07.0'},
#  {'createDt': '2022-09-29 08:09:25.0',
#   'deathCnt': '28363',
#   'decideCnt': '24740521',
#   'seq': '1020',
#   'stateDt': '20220929',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:33:27.0'},
#  {'createDt': '2022-09-28 08:03:50.0',
#   'deathCnt': '28317',
#   'decideCnt': '24709682',
#   'seq': '1019',
#   'stateDt': '20220928',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:33:50.0'},
#  {'createDt': '2022-09-27 08:11:13.0',
#   'deathCnt': '28271',
#   'decideCnt': '24673554',
#   'seq': '1018',
#   'stateDt': '20220927',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:34:03.0'},
#  {'createDt': '2022-09-26 08:12:34.0',
#   'deathCnt': '28245',
#   'decideCnt': '24634144',
#   'seq': '1017',
#   'stateDt': '20220926',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:34:16.0'},
#  {'createDt': '2022-09-25 09:32:52.0',
#   'deathCnt': '28212',
#   'decideCnt': '24619990',
#   'seq': '1016',
#   'stateDt': '20220925',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:34:36.0'},
#  {'createDt': '2022-09-24 09:12:23.0',
#   'deathCnt': '28139',
#   'decideCnt': '24594218',
#   'seq': '1015',
#   'stateDt': '20220924',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:34:47.0'},
#  {'createDt': '2022-09-23 08:09:32.0',
#   'deathCnt': '28076',
#   'decideCnt': '24564896',
#   'seq': '1014',
#   'stateDt': '20220923',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:35:01.0'},
#  {'createDt': '2022-09-22 08:24:18.0',
#   'deathCnt': '28008',
#   'decideCnt': '24535813',
#   'seq': '1013',
#   'stateDt': '20220922',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:35:25.0'},
#  {'createDt': '2022-09-21 08:06:02.0',
#   'deathCnt': '27949',
#   'decideCnt': '24502823',
#   'seq': '1012',
#   'stateDt': '20220921',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:37:53.0'},
#  {'createDt': '2022-09-20 08:12:32.0',
#   'deathCnt': '27890',
#   'decideCnt': '24461567',
#   'seq': '1011',
#   'stateDt': '20220920',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:16.0'},
#  {'createDt': '2022-09-19 08:04:07.0',
#   'deathCnt': '27866',
#   'decideCnt': '24413704',
#   'seq': '1010',
#   'stateDt': '20220919',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:29.0'},
#  {'createDt': '2022-09-18 09:04:34.0',
#   'deathCnt': '27827',
#   'decideCnt': '24394315',
#   'seq': '1009',
#   'stateDt': '20220918',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:39.0'},
#  {'createDt': '2022-09-17 09:32:44.0',
#   'deathCnt': '27781',
#   'decideCnt': '24359572',
#   'seq': '1008',
#   'stateDt': '20220917',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:49.0'},
#  {'createDt': '2022-09-16 08:55:16.0',
#   'deathCnt': '27724',
#   'decideCnt': '24316150',
#   'seq': '1007',
#   'stateDt': '20220916',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:58.0'},
#  {'createDt': '2022-09-15 08:57:18.0',
#   'deathCnt': '27664',
#   'decideCnt': '24264302',
#   'seq': '1006',
#   'stateDt': '20220915',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:39:11.0'},
#  {'createDt': '2022-09-14 09:13:17.0',
#   'deathCnt': '27592',
#   'decideCnt': '24192858',
#   'seq': '1005',
#   'stateDt': '20220914',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:39:23.0'},
#  {'createDt': '2022-09-13 08:58:44.0',
#   'deathCnt': '27532',
#   'decideCnt': '24098929',
#   'seq': '1004',
#   'stateDt': '20220913',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:39:35.0'},
#  {'createDt': '2022-09-12 09:22:11.0',
#   'deathCnt': '27497',
#   'decideCnt': '24041671',
#   'seq': '1003',
#   'stateDt': '20220912',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:39:53.0'},
#  {'createDt': '2022-09-11 09:16:56.0',
#   'deathCnt': '27475',
#   'decideCnt': '24004748',
#   'seq': '1002',
#   'stateDt': '20220911',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:40:06.0'},
#  {'createDt': '2022-09-10 10:45:37.0',
#   'deathCnt': '27428',
#   'decideCnt': '23976548',
#   'seq': '1001',
#   'stateDt': '20220910',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:40:52.0'},
#  {'createDt': '2022-09-09 09:15:06.0',
#   'deathCnt': '27380',
#   'decideCnt': '23933868',
#   'seq': '1000',
#   'stateDt': '20220909',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:41:02.0'},
#  {'createDt': '2022-09-08 09:09:48.0',
#   'deathCnt': '27312',
#   'decideCnt': '23864479',
#   'seq': '999',
#   'stateDt': '20220908',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:41:13.0'},
#  {'createDt': '2022-09-07 09:12:02.0',
#   'deathCnt': '27248',
#   'decideCnt': '23791862',
#   'seq': '998',
#   'stateDt': '20220907',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:41:23.0'},
#  {'createDt': '2022-09-06 08:57:40.0',
#   'deathCnt': '27192',
#   'decideCnt': '23706364',
#   'seq': '997',
#   'stateDt': '20220906',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:00.0'},
#  {'createDt': '2022-09-05 09:15:52.0',
#   'deathCnt': '27148',
#   'decideCnt': '23606542',
#   'seq': '996',
#   'stateDt': '20220905',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:09.0'},
#  {'createDt': '2022-09-04 09:00:53.0',
#   'deathCnt': '27092',
#   'decideCnt': '23569012',
#   'seq': '995',
#   'stateDt': '20220904',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:19.0'},
#  {'createDt': '2022-09-03 09:03:21.0',
#   'deathCnt': '27013',
#   'decideCnt': '23496885',
#   'seq': '994',
#   'stateDt': '20220903',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:27.0'},
#  {'createDt': '2022-09-02 08:07:32.0',
#   'deathCnt': '26939',
#   'decideCnt': '23417164',
#   'seq': '993',
#   'stateDt': '20220902',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:40.0'},
#  {'createDt': '2022-09-01 08:44:16.0',
#   'deathCnt': '26875',
#   'decideCnt': '23327609',
#   'seq': '992',
#   'stateDt': '20220901',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:42:50.0'},
#  {'createDt': '2022-08-31 08:15:32.0',
#   'deathCnt': '26763',
#   'decideCnt': '23246075',
#   'seq': '991',
#   'stateDt': '20220831',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:43:04.0'},
#  {'createDt': '2022-08-30 08:07:00.0',
#   'deathCnt': '26688',
#   'decideCnt': '23142227',
#   'seq': '990',
#   'stateDt': '20220830',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:43:16.0'},
#  {'createDt': '2022-08-29 09:04:40.0',
#   'deathCnt': '26617',
#   'decideCnt': '23026612',
#   'seq': '989',
#   'stateDt': '20220829',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:43:31.0'},
#  {'createDt': '2022-08-28 09:23:20.0',
#   'deathCnt': '26568',
#   'decideCnt': '22983498',
#   'seq': '988',
#   'stateDt': '20220828',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:43:46.0'},
#  {'createDt': '2022-08-27 09:10:24.0',
#   'deathCnt': '26498',
#   'decideCnt': '22898265',
#   'seq': '987',
#   'stateDt': '20220827',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:43:55.0'},
#  {'createDt': '2022-08-26 08:55:24.0',
#   'deathCnt': '26412',
#   'decideCnt': '22802779',
#   'seq': '986',
#   'stateDt': '20220826',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:44:05.0'},
#  {'createDt': '2022-08-25 08:50:21.0',
#   'deathCnt': '26331',
#   'decideCnt': '22701686',
#   'seq': '985',
#   'stateDt': '20220825',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:44:18.0'},
#  {'createDt': '2022-08-24 08:50:29.0',
#   'deathCnt': '26223',
#   'decideCnt': '22588367',
#   'seq': '984',
#   'stateDt': '20220824',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:44:30.0'},
#  {'createDt': '2022-08-23 09:00:22.0',
#   'deathCnt': '26160',
#   'decideCnt': '22449064',
#   'seq': '983',
#   'stateDt': '20220823',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:44:45.0'},
#  {'createDt': '2022-08-22 08:10:20.0',
#   'deathCnt': '26108',
#   'decideCnt': '22298898',
#   'seq': '982',
#   'stateDt': '20220822',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:47:27.0'},
#  {'createDt': '2022-08-21 09:23:58.0',
#   'deathCnt': '26043',
#   'decideCnt': '22239879',
#   'seq': '981',
#   'stateDt': '20220821',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:47:39.0'},
#  {'createDt': '2022-08-20 09:16:38.0',
#   'deathCnt': '25979',
#   'decideCnt': '22128971',
#   'seq': '980',
#   'stateDt': '20220820',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:47:52.0'},
#  {'createDt': '2022-08-19 08:59:50.0',
#   'deathCnt': '25895',
#   'decideCnt': '21999631',
#   'seq': '979',
#   'stateDt': '20220819',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:07.0'},
#  {'createDt': '2022-08-18 08:54:41.0',
#   'deathCnt': '25812',
#   'decideCnt': '21860883',
#   'seq': '978',
#   'stateDt': '20220818',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:15.0'},
#  {'createDt': '2022-08-17 06:24:10.0',
#   'deathCnt': '25751',
#   'decideCnt': '21682395',
#   'seq': '977',
#   'stateDt': '20220817',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:24.0'},
#  {'createDt': '2022-08-16 06:27:26.0',
#   'deathCnt': '25709',
#   'decideCnt': '21501742',
#   'seq': '976',
#   'stateDt': '20220816',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:34.0'},
#  {'createDt': '2022-08-15 09:06:28.0',
#   'deathCnt': '25672',
#   'decideCnt': '21417737',
#   'seq': '975',
#   'stateDt': '20220815',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:44.0'},
#  {'createDt': '2022-08-14 09:04:15.0',
#   'deathCnt': '25622',
#   'decideCnt': '21355681',
#   'seq': '974',
#   'stateDt': '20220814',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:48:56.0'},
#  {'createDt': '2022-08-13 09:05:17.0',
#   'deathCnt': '25565',
#   'decideCnt': '21236135',
#   'seq': '973',
#   'stateDt': '20220813',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:49:10.0'},
#  {'createDt': '2022-08-12 08:40:20.0',
#   'deathCnt': '25498',
#   'decideCnt': '21111590',
#   'seq': '972',
#   'stateDt': '20220812',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:49:53.0'},
#  {'createDt': '2022-08-11 09:10:29.0',
#   'deathCnt': '25440',
#   'decideCnt': '20982950',
#   'seq': '971',
#   'stateDt': '20220811',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:50:12.0'},
#  {'createDt': '2022-08-10 09:21:32.0',
#   'deathCnt': '25381',
#   'decideCnt': '20845787',
#   'seq': '970',
#   'stateDt': '20220810',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:50:33.0'},
#  {'createDt': '2022-08-09 09:06:13.0',
#   'deathCnt': '25331',
#   'decideCnt': '20694097',
#   'seq': '969',
#   'stateDt': '20220809',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:50:47.0'},
#  {'createDt': '2022-08-08 09:03:33.0',
#   'deathCnt': '25291',
#   'decideCnt': '20544231',
#   'seq': '968',
#   'stateDt': '20220808',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:51:00.0'},
#  {'createDt': '2022-08-07 09:06:42.0',
#   'deathCnt': '25262',
#   'decideCnt': '20488969',
#   'seq': '967',
#   'stateDt': '20220807',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:52:45.0'},
#  {'createDt': '2022-08-06 09:05:09.0',
#   'deathCnt': '25235',
#   'decideCnt': '20383501',
#   'seq': '966',
#   'stateDt': '20220806',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:52:59.0'},
#  {'createDt': '2022-08-05 08:19:11.0',
#   'deathCnt': '25190',
#   'decideCnt': '20272882',
#   'seq': '965',
#   'stateDt': '20220805',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:15.0'},
#  {'createDt': '2022-08-04 08:58:06.0',
#   'deathCnt': '25143',
#   'decideCnt': '20160027',
#   'seq': '964',
#   'stateDt': '20220804',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:32.0'},
#  {'createDt': '2022-08-03 09:01:06.0',
#   'deathCnt': '25109',
#   'decideCnt': '20052173',
#   'seq': '963',
#   'stateDt': '20220803',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:50.0'},
#  {'createDt': '2022-08-02 09:02:53.0',
#   'deathCnt': '25083',
#   'decideCnt': '19932291',
#   'seq': '962',
#   'stateDt': '20220802',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:04.0'},
#  {'createDt': '2022-08-01 09:00:03.0',
#   'deathCnt': '25067',
#   'decideCnt': '19820538',
#   'seq': '961',
#   'stateDt': '20220801',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:16.0'},
#  {'createDt': '2022-07-31 08:57:39.0',
#   'deathCnt': '25046',
#   'decideCnt': '19775884',
#   'seq': '960',
#   'stateDt': '20220731',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:27.0'},
#  {'createDt': '2022-07-30 07:41:25.0',
#   'deathCnt': '25026',
#   'decideCnt': '19702325',
#   'seq': '959',
#   'stateDt': '20220730',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:36.0'},
#  {'createDt': '2022-07-29 08:58:16.0',
#   'deathCnt': '24991',
#   'decideCnt': '19620354',
#   'seq': '958',
#   'stateDt': '20220729',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:46.0'},
#  {'createDt': '2022-07-28 08:47:13.0',
#   'deathCnt': '24956',
#   'decideCnt': '19535065',
#   'seq': '957',
#   'stateDt': '20220728',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:55.0'},
#  {'createDt': '2022-07-27 09:12:50.0',
#   'deathCnt': '24931',
#   'decideCnt': '19446717',
#   'seq': '956',
#   'stateDt': '20220727',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:10.0'},
#  {'createDt': '2022-07-26 09:02:45.0',
#   'deathCnt': '24906',
#   'decideCnt': '19346477',
#   'seq': '955',
#   'stateDt': '20220726',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:20.0'},
#  {'createDt': '2022-07-25 09:13:10.0',
#   'deathCnt': '24889',
#   'decideCnt': '19247261',
#   'seq': '954',
#   'stateDt': '20220725',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:32.0'},
#  {'createDt': '2022-07-24 09:07:36.0',
#   'deathCnt': '24872',
#   'decideCnt': '19211401',
#   'seq': '953',
#   'stateDt': '20220724',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:45.0'},
#  {'createDt': '2022-07-23 09:11:03.0',
#   'deathCnt': '24854',
#   'decideCnt': '19146028',
#   'seq': '952',
#   'stateDt': '20220723',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:02.0'},
#  {'createDt': '2022-07-22 09:02:15.0',
#   'deathCnt': '24824',
#   'decideCnt': '19077520',
#   'seq': '951',
#   'stateDt': '20220722',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:12.0'},
#  {'createDt': '2022-07-21 08:58:37.0',
#   'deathCnt': '24793',
#   'decideCnt': '19008926',
#   'seq': '950',
#   'stateDt': '20220721',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:21.0'},
#  {'createDt': '2022-07-20 09:10:31.0',
#   'deathCnt': '24776',
#   'decideCnt': '18937795',
#   'seq': '949',
#   'stateDt': '20220720',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:35.0'},
#  {'createDt': '2022-07-19 09:08:28.0',
#   'deathCnt': '24764',
#   'decideCnt': '18861450',
#   'seq': '948',
#   'stateDt': '20220719',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:46.0'},
#  {'createDt': '2022-07-18 09:14:24.0',
#   'deathCnt': '24752',
#   'decideCnt': '18787908',
#   'seq': '947',
#   'stateDt': '20220718',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:01.0'},
#  {'createDt': '2022-07-17 09:20:40.0',
#   'deathCnt': '24741',
#   'decideCnt': '18761129',
#   'seq': '946',
#   'stateDt': '20220717',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:12.0'},
#  {'createDt': '2022-07-16 09:24:11.0',
#   'deathCnt': '24727',
#   'decideCnt': '18721303',
#   'seq': '945',
#   'stateDt': '20220716',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:24.0'},
#  {'createDt': '2022-07-15 09:05:32.0',
#   'deathCnt': '24711',
#   'decideCnt': '18680000',
#   'seq': '944',
#   'stateDt': '20220715',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:33.0'},
#  {'createDt': '2022-07-14 09:13:54.0',
#   'deathCnt': '24695',
#   'decideCnt': '18641158',
#   'seq': '943',
#   'stateDt': '20220714',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:43.0'},
#  {'createDt': '2022-07-13 09:05:07.0',
#   'deathCnt': '24679',
#   'decideCnt': '18602014',
#   'seq': '942',
#   'stateDt': '20220713',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:54.0'},
#  {'createDt': '2022-07-12 04:00:24.0',
#   'deathCnt': '24667',
#   'decideCnt': '18561766',
#   'seq': '941',
#   'stateDt': '20220712',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:51.0'},
#  {'createDt': '2022-07-11 06:10:35.0',
#   'deathCnt': '24660',
#   'decideCnt': '18524435',
#   'seq': '940',
#   'stateDt': '20220711',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:43.0'},
#  {'createDt': '2022-07-10 09:20:10.0',
#   'deathCnt': '24642',
#   'decideCnt': '18511754',
#   'seq': '939',
#   'stateDt': '20220710',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:30.0'},
#  {'createDt': '2022-07-09 09:17:26.0',
#   'deathCnt': '24623',
#   'decideCnt': '18491357',
#   'seq': '938',
#   'stateDt': '20220709',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:23.0'},
#  {'createDt': '2022-07-08 06:22:27.0',
#   'deathCnt': '24604',
#   'decideCnt': '18471097',
#   'seq': '937',
#   'stateDt': '20220708',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:13.0'},
#  {'createDt': '2022-07-07 06:13:49.0',
#   'deathCnt': '24592',
#   'decideCnt': '18451799',
#   'seq': '935',
#   'stateDt': '20220707',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:57:05.0'},
#  {'createDt': '2022-07-06 09:09:17.0',
#   'deathCnt': '24582',
#   'decideCnt': '18433301',
#   'seq': '934',
#   'stateDt': '20220706',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:58.0'},
#  {'createDt': '2022-07-05 08:52:18.0',
#   'deathCnt': '24575',
#   'decideCnt': '18413942',
#   'seq': '933',
#   'stateDt': '20220705',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:51.0'},
#  {'createDt': '2022-07-04 09:15:45.0',
#   'deathCnt': '24573',
#   'decideCnt': '18395822',
#   'seq': '932',
#   'stateDt': '20220704',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:44.0'},
#  {'createDt': '2022-07-03 08:56:14.0',
#   'deathCnt': '24569',
#   'decideCnt': '18389573',
#   'seq': '931',
#   'stateDt': '20220703',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:37.0'},
#  {'createDt': '2022-07-02 10:00:18.0',
#   'deathCnt': '24561',
#   'decideCnt': '18379525',
#   'seq': '930',
#   'stateDt': '20220702',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:28.0'},
#  {'createDt': '2022-07-01 08:48:46.0',
#   'deathCnt': '24554',
#   'decideCnt': '18368824',
#   'seq': '929',
#   'stateDt': '20220701',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:18.0'},
#  {'createDt': '2022-06-30 09:01:12.0',
#   'deathCnt': '24546',
#   'decideCnt': '18359307',
#   'seq': '928',
#   'stateDt': '20220630',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:10.0'},
#  {'createDt': '2022-06-29 09:12:36.0',
#   'deathCnt': '24536',
#   'decideCnt': '18349716',
#   'seq': '927',
#   'stateDt': '20220629',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:56:02.0'},
#  {'createDt': '2022-06-28 08:52:34.0',
#   'deathCnt': '24529',
#   'decideCnt': '18339262',
#   'seq': '926',
#   'stateDt': '20220628',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:54.0'},
#  {'createDt': '2022-06-27 09:11:58.0',
#   'deathCnt': '24524',
#   'decideCnt': '18329369',
#   'seq': '924',
#   'stateDt': '20220627',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:47.0'},
#  {'createDt': '2022-06-26 09:27:03.0',
#   'deathCnt': '24521',
#   'decideCnt': '18325946',
#   'seq': '923',
#   'stateDt': '20220626',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:40.0'},
#  {'createDt': '2022-06-25 09:32:40.0',
#   'deathCnt': '24515',
#   'decideCnt': '18319708',
#   'seq': '922',
#   'stateDt': '20220625',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:33.0'},
#  {'createDt': '2022-06-24 09:05:53.0',
#   'deathCnt': '24497',
#   'decideCnt': '18312935',
#   'seq': '921',
#   'stateDt': '20220624',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:26.0'},
#  {'createDt': '2022-06-23 09:06:53.0',
#   'deathCnt': '24487',
#   'decideCnt': '18305719',
#   'seq': '920',
#   'stateDt': '20220623',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:12.0'},
#  {'createDt': '2022-06-22 09:03:09.0',
#   'deathCnt': '24473',
#   'decideCnt': '18298231',
#   'seq': '918',
#   'stateDt': '20220622',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:55:05.0'},
#  {'createDt': '2022-06-21 09:06:00.0',
#   'deathCnt': '24462',
#   'decideCnt': '18289265',
#   'seq': '917',
#   'stateDt': '20220621',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:58.0'},
#  {'createDt': '2022-06-20 09:06:19.0',
#   'deathCnt': '24450',
#   'decideCnt': '18279976',
#   'seq': '916',
#   'stateDt': '20220620',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:52.0'},
#  {'createDt': '2022-06-19 07:40:29.0',
#   'deathCnt': '24440',
#   'decideCnt': '18276443',
#   'seq': '915',
#   'stateDt': '20220619',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:44.0'},
#  {'createDt': '2022-06-18 08:16:08.0',
#   'deathCnt': '24426',
#   'decideCnt': '18270377',
#   'seq': '914',
#   'stateDt': '20220618',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:38.0'},
#  {'createDt': '2022-06-17 09:03:13.0',
#   'deathCnt': '24415',
#   'decideCnt': '18263556',
#   'seq': '913',
#   'stateDt': '20220617',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:30.0'},
#  {'createDt': '2022-06-16 08:59:50.0',
#   'deathCnt': '24406',
#   'decideCnt': '18256364',
#   'seq': '912',
#   'stateDt': '20220616',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:22.0'},
#  {'createDt': '2022-06-15 09:10:38.0',
#   'deathCnt': '24398',
#   'decideCnt': '18248422',
#   'seq': '911',
#   'stateDt': '20220615',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:15.0'},
#  {'createDt': '2022-06-14 09:08:41.0',
#   'deathCnt': '24389',
#   'decideCnt': '18239008',
#   'seq': '910',
#   'stateDt': '20220614',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:08.0'},
#  {'createDt': '2022-06-13 09:15:46.0',
#   'deathCnt': '24387',
#   'decideCnt': '18229246',
#   'seq': '909',
#   'stateDt': '20220613',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:54:00.0'},
#  {'createDt': '2022-06-12 09:15:29.0',
#   'deathCnt': '24370',
#   'decideCnt': '18225423',
#   'seq': '908',
#   'stateDt': '20220612',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:52.0'},
#  {'createDt': '2022-06-11 09:17:30.0',
#   'deathCnt': '24350',
#   'decideCnt': '18218046',
#   'seq': '907',
#   'stateDt': '20220611',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:44.0'},
#  {'createDt': '2022-06-10 09:11:25.0',
#   'deathCnt': '24340',
#   'decideCnt': '18209608',
#   'seq': '906',
#   'stateDt': '20220610',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:35.0'},
#  {'createDt': '2022-06-09 09:07:31.0',
#   'deathCnt': '24322',
#   'decideCnt': '18200302',
#   'seq': '905',
#   'stateDt': '20220609',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:53:28.0'},
#  {'createDt': '2022-06-08 09:09:05.0',
#   'deathCnt': '24304',
#   'decideCnt': '18188153',
#   'seq': '904',
# ...
#   'deathCnt': '12100',
#   'decideCnt': '9038522',
#   'seq': '822',
#   'stateDt': '20220319',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:38:01.0'},
#  {'createDt': '2022-03-18 09:06:55.0',
#   'deathCnt': '11781',
#   'decideCnt': '8657109',
#   'seq': '821',
#   'stateDt': '20220318',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:37:52.0'},
#  {'createDt': '2022-03-17 09:28:28.0',
#   'deathCnt': '11480',
#   'decideCnt': '8250270',
#   'seq': '820',
#   'stateDt': '20220317',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:37:42.0'},
#  {'createDt': '2022-03-16 09:07:33.0',
#   'deathCnt': '11051',
#   'decideCnt': '7629066',
#   'seq': '819',
#   'stateDt': '20220316',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:37:31.0'},
#  {'createDt': '2022-03-15 09:08:41.0',
#   'deathCnt': '10887',
#   'decideCnt': '7228473',
#   'seq': '818',
#   'stateDt': '20220315',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:37:16.0'},
#  {'createDt': '2022-03-14 09:01:32.0',
#   'deathCnt': '10594',
#   'decideCnt': '6866190',
#   'seq': '817',
#   'stateDt': '20220314',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:32:58.0'},
#  {'createDt': '2022-03-13 09:13:37.0',
#   'deathCnt': '10394',
#   'decideCnt': '6556411',
#   'seq': '816',
#   'stateDt': '20220313',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:32:46.0'},
#  {'createDt': '2022-03-12 08:53:24.0',
#   'deathCnt': '10143',
#   'decideCnt': '6206229',
#   'seq': '815',
#   'stateDt': '20220312',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:32:28.0'},
#  {'createDt': '2022-03-11 08:56:23.0',
#   'deathCnt': '9874',
#   'decideCnt': '5822612',
#   'seq': '814',
#   'stateDt': '20220311',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:32:15.0'},
#  {'createDt': '2022-03-10 09:07:48.0',
#   'deathCnt': '9645',
#   'decideCnt': '5539639',
#   'seq': '813',
#   'stateDt': '20220310',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:31:56.0'},
#  {'createDt': '2022-03-09 08:57:50.0',
#   'deathCnt': '9439',
#   'decideCnt': '5212101',
#   'seq': '812',
#   'stateDt': '20220309',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:31:45.0'},
#  {'createDt': '2022-03-08 08:58:30.0',
#   'deathCnt': '9281',
#   'decideCnt': '4869672',
#   'seq': '811',
#   'stateDt': '20220308',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:31:33.0'},
#  {'createDt': '2022-03-07 09:06:07.0',
#   'deathCnt': '9095',
#   'decideCnt': '4666970',
#   'seq': '810',
#   'stateDt': '20220307',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:31:19.0'},
#  {'createDt': '2022-03-06 09:40:46.0',
#   'deathCnt': '8956',
#   'decideCnt': '4456261',
#   'seq': '809',
#   'stateDt': '20220306',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:30:58.0'},
#  {'createDt': '2022-03-05 09:41:58.0',
#   'deathCnt': '8795',
#   'decideCnt': '4212636',
#   'seq': '808',
#   'stateDt': '20220305',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:16:26.0'},
#  {'createDt': '2022-03-04 08:59:56.0',
#   'deathCnt': '8579',
#   'decideCnt': '3958309',
#   'seq': '807',
#   'stateDt': '20220304',
#   'stateTime': '00:00',
#   'updateDt': '2022-11-05 10:02:18.0'},
#  {'createDt': '2022-03-03 09:08:34.548',
#   'deathCnt': '8394',
#   'decideCnt': '3691459',
#   'seq': '806',
#   'stateDt': '20220303',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:41:48.252'},
#  {'createDt': '2022-03-02 09:05:42.681',
#   'deathCnt': '8266',
#   'decideCnt': '3492659',
#   'seq': '805',
#   'stateDt': '20220302',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:03.65'},
#  {'createDt': '2022-03-01 09:12:42.55',
#   'deathCnt': '8170',
#   'decideCnt': '3273431',
#   'seq': '804',
#   'stateDt': '20220301',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:18.383'},
#  {'createDt': '2022-02-28 08:56:05.34',
#   'deathCnt': '8058',
#   'decideCnt': '3134441',
#   'seq': '803',
#   'stateDt': '20220228',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:40.367'},
#  {'createDt': '2022-02-27 08:54:59.059',
#   'deathCnt': '7944',
#   'decideCnt': '2994817',
#   'seq': '802',
#   'stateDt': '20220227',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:43:04.008'},
#  {'createDt': '2022-02-26 09:10:30.918',
#   'deathCnt': '7895',
#   'decideCnt': '2831256',
#   'seq': '801',
#   'stateDt': '20220226',
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:45:32.611'},
#  {'createDt': '2022-02-25 09:19:35.533',
#   'deathCnt': '7783',
#   'decideCnt': '2665074',
#   'seq': '800',
#   'stateDt': '20220225',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-26 09:11:20.409'},
#  {'createDt': '2022-02-24 09:45:42.528',
#   'deathCnt': '7689',
#   'decideCnt': '2499187',
#   'seq': '799',
#   'stateDt': '20220224',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-25 09:19:57.585'},
#  {'createDt': '2022-02-23 09:12:48.876',
#   'deathCnt': '7607',
#   'decideCnt': '2329172',
#   'seq': '798',
#   'stateDt': '20220223',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-24 09:46:50.038'},
#  {'createDt': '2022-02-22 09:06:38.772',
#   'deathCnt': '7508',
#   'decideCnt': '2157730',
#   'seq': '797',
#   'stateDt': '20220222',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-23 09:13:50.655'},
#  {'createDt': '2022-02-21 09:05:08.307',
#   'deathCnt': '7450',
#   'decideCnt': '2058161',
#   'seq': '796',
#   'stateDt': '20220221',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-22 09:07:07.41'},
#  {'createDt': '2022-02-20 08:51:11.122',
#   'deathCnt': '7405',
#   'decideCnt': '1962822',
#   'seq': '795',
#   'stateDt': '20220220',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-21 09:05:38.992'},
#  {'createDt': '2022-02-19 09:00:04.109',
#   'deathCnt': '7354',
#   'decideCnt': '1858008',
#   'seq': '794',
#   'stateDt': '20220219',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-20 08:52:45.133'},
#  {'createDt': '2022-02-18 09:04:59.618',
#   'deathCnt': '7283',
#   'decideCnt': '1755798',
#   'seq': '793',
#   'stateDt': '20220218',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-19 09:00:52.083'},
#  {'createDt': '2022-02-17 08:52:05.139',
#   'deathCnt': '7238',
#   'decideCnt': '1645975',
#   'seq': '792',
#   'stateDt': '20220217',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-18 09:05:35.842'},
#  {'createDt': '2022-02-16 09:20:27.8',
#   'deathCnt': '7202',
#   'decideCnt': '1552843',
#   'seq': '791',
#   'stateDt': '20220216',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-17 08:52:33.561'},
#  {'createDt': '2022-02-15 09:01:44.846',
#   'deathCnt': '7163',
#   'decideCnt': '1462408',
#   'seq': '790',
#   'stateDt': '20220215',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-16 09:20:55.138'},
#  {'createDt': '2022-02-14 09:01:51.395',
#   'deathCnt': '7102',
#   'decideCnt': '1405244',
#   'seq': '789',
#   'stateDt': '20220214',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-15 09:02:24.905'},
#  {'createDt': '2022-02-13 08:50:26.798',
#   'deathCnt': '7081',
#   'decideCnt': '1350627',
#   'seq': '788',
#   'stateDt': '20220213',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-14 09:03:09.631'},
#  {'createDt': '2022-02-12 09:06:44.105',
#   'deathCnt': '7045',
#   'decideCnt': '1294199',
#   'seq': '787',
#   'stateDt': '20220212',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-13 08:50:59.578'},
#  {'createDt': '2022-02-11 08:37:42.029',
#   'deathCnt': '7012',
#   'decideCnt': '1239264',
#   'seq': '786',
#   'stateDt': '20220211',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-12 22:25:54.07'},
#  {'createDt': '2022-02-10 09:04:23.377',
#   'deathCnt': '6963',
#   'decideCnt': '1185361',
#   'seq': '785',
#   'stateDt': '20220210',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-10 09:06:18.131'},
#  {'createDt': '2022-02-09 10:37:00.08',
#   'deathCnt': '6943',
#   'decideCnt': '1131239',
#   'seq': '784',
#   'stateDt': '20220209',
#   'stateTime': '00:00'},
#  {'createDt': '2022-02-08 10:14:19.994',
#   'deathCnt': '6922',
#   'decideCnt': '1081672',
#   'seq': '783',
#   'stateDt': '20220208',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:32.357'},
#  {'createDt': '2022-02-07 09:01:20.8',
#   'deathCnt': '6886',
#   'decideCnt': '1044955',
#   'seq': '782',
#   'stateDt': '20220207',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:22.271'},
#  {'createDt': '2022-02-06 09:21:40.142',
#   'deathCnt': '6873',
#   'decideCnt': '1009672',
#   'seq': '781',
#   'stateDt': '20220206',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:11.818'},
#  {'createDt': '2022-02-05 10:25:08.782',
#   'deathCnt': '6858',
#   'decideCnt': '970983',
#   'seq': '780',
#   'stateDt': '20220205',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:01.221'},
#  {'createDt': '2022-02-04 08:58:40.476',
#   'deathCnt': '6836',
#   'decideCnt': '934638',
#   'seq': '779',
#   'stateDt': '20220204',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:52.382'},
#  {'createDt': '2022-02-03 08:46:14.856',
#   'deathCnt': '6812',
#   'decideCnt': '907200',
#   'seq': '778',
#   'stateDt': '20220203',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:42.741'},
#  {'createDt': '2022-02-02 09:04:49.92',
#   'deathCnt': '6787',
#   'decideCnt': '884294',
#   'seq': '777',
#   'stateDt': '20220202',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:29.013'},
#  {'createDt': '2022-02-01 09:06:24.411',
#   'deathCnt': '6772',
#   'decideCnt': '864026',
#   'seq': '776',
#   'stateDt': '20220201',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:21.424'},
#  {'accExamCnt': '21518073',
#   'createDt': '2022-01-31 09:22:37.347',
#   'deathCnt': '6755',
#   'decideCnt': '845688',
#   'seq': '775',
#   'stateDt': '20220131',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-07 09:06:04.861'},
#  {'accExamCnt': '21448119',
#   'createDt': '2022-01-30 09:13:00.269',
#   'deathCnt': '6732',
#   'decideCnt': '828611',
#   'seq': '774',
#   'stateDt': '20220130',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-07 09:05:54.937'},
#  {'accExamCnt': '21377393',
#   'createDt': '2022-01-29 08:46:05.752',
#   'deathCnt': '6712',
#   'decideCnt': '811089',
#   'seq': '773',
#   'stateDt': '20220129',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-04 08:59:02.84'},
#  {'accExamCnt': '21269304',
#   'createDt': '2022-01-28 09:04:52.588',
#   'deathCnt': '6678',
#   'decideCnt': '793576',
#   'seq': '772',
#   'stateDt': '20220128',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-04 08:58:55.443'},
#  {'accExamCnt': '21196354',
#   'createDt': '2022-01-27 09:04:10.687',
#   'deathCnt': '6654',
#   'decideCnt': '777483',
#   'seq': '771',
#   'stateDt': '20220127',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:05:52.264'},
#  {'accExamCnt': '21110639',
#   'createDt': '2022-01-26 08:59:34.44',
#   'deathCnt': '6620',
#   'decideCnt': '762969',
#   'seq': '770',
#   'stateDt': '20220126',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:06:04.543'},
#  {'accExamCnt': '21026346',
#   'createDt': '2022-01-25 08:58:23.511',
#   'deathCnt': '6588',
#   'decideCnt': '749960',
#   'seq': '769',
#   'stateDt': '20220125',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:06:12.847'},
#  {'accExamCnt': '20943638',
#   'createDt': '2022-01-24 08:59:37.815',
#   'deathCnt': '6565',
#   'decideCnt': '741390',
#   'seq': '768',
#   'stateDt': '20220124',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:06:21.743'},
#  {'accExamCnt': '20892539',
#   'createDt': '2022-01-23 08:13:23.247',
#   'deathCnt': '6540',
#   'decideCnt': '733879',
#   'seq': '767',
#   'stateDt': '20220123',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:06:30.706'},
#  {'accExamCnt': '20838500',
#   'createDt': '2022-01-22 07:26:15.458',
#   'deathCnt': '6529',
#   'decideCnt': '726253',
#   'seq': '766',
#   'stateDt': '20220122',
#   'stateTime': '00:00',
#   'updateDt': '2022-02-02 09:06:40.166'},
#  {'accExamCnt': '20765930',
#   'createDt': '2022-01-21 08:55:49.63',
#   'deathCnt': '6501',
#   'decideCnt': '719249',
#   'seq': '765',
#   'stateDt': '20220121',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:07:28.893'},
#  {'accExamCnt': '20709568',
#   'createDt': '2022-01-20 09:15:13.261',
#   'deathCnt': '6480',
#   'decideCnt': '712483',
#   'seq': '764',
#   'stateDt': '20220120',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:07:20.195'},
#  {'accExamCnt': '20649522',
#   'createDt': '2022-01-19 09:01:30.801',
#   'deathCnt': '6452',
#   'decideCnt': '705883',
#   'seq': '763',
#   'stateDt': '20220119',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:07:08.094'},
#  {'accExamCnt': '20588481',
#   'createDt': '2022-01-18 09:03:38.28',
#   'deathCnt': '6378',
#   'decideCnt': '700080',
#   'seq': '762',
#   'stateDt': '20220118',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:07:01.638'},
#  {'accExamCnt': '20527722',
#   'createDt': '2022-01-17 09:03:38.424',
#   'deathCnt': '6333',
#   'decideCnt': '696018',
#   'seq': '761',
#   'stateDt': '20220117',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:06:55.793'},
#  {'accExamCnt': '20489023',
#   'createDt': '2022-01-16 09:31:40.897',
#   'deathCnt': '6310',
#   'decideCnt': '692164',
#   'seq': '760',
#   'stateDt': '20220116',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-28 09:06:48.796'},
#  {'accExamCnt': '20446099',
#   'createDt': '2022-01-15 08:17:22.717',
#   'deathCnt': '6281',
#   'decideCnt': '687975',
#   'seq': '759',
#   'stateDt': '20220115',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-20 09:15:33.87'},
#  {'accExamCnt': '20389154',
#   'createDt': '2022-01-14 08:59:27.905',
#   'deathCnt': '6259',
#   'decideCnt': '683556',
#   'seq': '758',
#   'stateDt': '20220114',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-19 09:03:44.328'},
#  {'accExamCnt': '20329715',
#   'createDt': '2022-01-13 08:43:16.692',
#   'deathCnt': '6210',
#   'decideCnt': '679018',
#   'seq': '757',
#   'stateDt': '20220113',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-19 09:03:32.883'},
#  {'accExamCnt': '20277357',
#   'createDt': '2022-01-12 09:08:49.646',
#   'deathCnt': '6166',
#   'decideCnt': '674854',
#   'seq': '756',
#   'stateDt': '20220112',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-19 09:03:22.963'},
#  {'accExamCnt': '20215297',
#   'createDt': '2022-01-11 09:07:41.087',
#   'deathCnt': '6114',
#   'decideCnt': '670471',
#   'seq': '755',
#   'stateDt': '20220111',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-24 14:20:11.807'},
#  {'accExamCnt': '20148476',
#   'createDt': '2022-01-10 09:06:03.096',
#   'deathCnt': '6071',
#   'decideCnt': '667379',
#   'seq': '754',
#   'stateDt': '20220110',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-16 11:07:18.403'},
#  {'accExamCnt': '20099870',
#   'createDt': '2022-01-09 08:47:53.411',
#   'deathCnt': '6037',
#   'decideCnt': '664374',
#   'seq': '753',
#   'stateDt': '20220109',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-16 11:07:25.748'},
#  {'accExamCnt': '20046220',
#   'createDt': '2022-01-08 08:38:42.084',
#   'deathCnt': '5986',
#   'decideCnt': '661003',
#   'seq': '752',
#   'stateDt': '20220108',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-16 11:07:34.017'},
#  {'accExamCnt': '19971712',
#   'createDt': '2022-01-07 09:04:22.334',
#   'deathCnt': '5932',
#   'decideCnt': '657496',
#   'seq': '751',
#   'stateDt': '20220107',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-14 09:00:38.585'},
#  {'accExamCnt': '19875047',
#   'createDt': '2022-01-06 08:59:04.372',
#   'deathCnt': '5887',
#   'decideCnt': '653783',
#   'seq': '750',
#   'stateDt': '20220106',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-14 09:00:27.23'},
#  {'accExamCnt': '19778824',
#   'createDt': '2022-01-05 09:01:59.247',
#   'deathCnt': '5838',
#   'decideCnt': '649661',
#   'seq': '749',
#   'stateDt': '20220105',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-12 09:09:21.324'},
#  {'accExamCnt': '19671880',
#   'createDt': '2022-01-04 09:04:35.476',
#   'deathCnt': '5781',
#   'decideCnt': '645220',
#   'seq': '748',
#   'stateDt': '20220104',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-12 09:09:14.713'},
#  {'accExamCnt': '19546883',
#   'createDt': '2022-01-03 08:58:35.591',
#   'deathCnt': '5730',
#   'decideCnt': '642199',
#   'seq': '747',
#   'stateDt': '20220103',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-08 09:40:28.974'},
#  {'accExamCnt': '19456900',
#   'createDt': '2022-01-02 08:57:24.688',
#   'deathCnt': '5694',
#   'decideCnt': '639074',
#   'seq': '746',
#   'stateDt': '20220102',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-08 09:40:16.808'},
#  {'accExamCnt': '19364122',
#   'createDt': '2022-01-01 09:02:39.218',
#   'deathCnt': '5625',
#   'decideCnt': '635243',
#   'seq': '745',
#   'stateDt': '20220101',
#   'stateTime': '00:00',
#   'updateDt': '2022-01-08 09:40:05.3'}]

# %%
rows = result['response']['body']['items']['item']

# %%
df = pd.DataFrame(rows)
df
# Out:
#                     createDt deathCnt decideCnt   seq   stateDt stateTime  \
# 0      2023-02-10 04:22:09.0    33697  30325343  1159  20230210     00:00
# 1      2023-02-09 00:13:08.0    33680  30311839  1158  20230209     00:00
# 2      2023-02-08 00:10:49.0    33646  30297177  1157  20230208     00:00
# 3      2023-02-07 04:25:43.0    33624  30279250  1156  20230207     00:00
# 4      2023-02-06 04:20:35.0    33614  30263138  1155  20230206     00:00
# ..                       ...      ...       ...   ...       ...       ...
# 400  2022-01-05 09:01:59.247     5838    649661   749  20220105     00:00
# 401  2022-01-04 09:04:35.476     5781    645220   748  20220104     00:00
# 402  2022-01-03 08:58:35.591     5730    642199   747  20220103     00:00
# 403  2022-01-02 08:57:24.688     5694    639074   746  20220102     00:00
# 404  2022-01-01 09:02:39.218     5625    635243   745  20220101     00:00
#
#                     updateDt accExamCnt
# 0      2023-02-11 06:02:40.0        NaN
# 1      2023-02-11 06:03:21.0        NaN
# 2      2023-02-11 06:03:54.0        NaN
# 3      2023-02-11 06:04:17.0        NaN
# 4      2023-02-11 06:04:43.0        NaN
# ..                       ...        ...
# 400  2022-01-12 09:09:21.324   19778824
# 401  2022-01-12 09:09:14.713   19671880
# 402  2022-01-08 09:40:28.974   19546883
# 403  2022-01-08 09:40:16.808   19456900
# 404    2022-01-08 09:40:05.3   19364122
#
# [405 rows x 8 columns]

# %%
## pandas를 이용하여 csv로 파일 저장
df.to_csv("corona.csv", encoding='UTF-8')
